# %%
import pandas as pd

# %%
patient11 = pd.read_excel("../patientid_11_vwd_summary.xlsx")

# %%
patient11.head()
# Out:
#    Unnamed: 0  Patient Id  BN  ventBN     BS   IEnd    BE  I:E ratio  iTime  \
# 0           0          11   1       0   0.02  10.40  10.4  519.00000  10.38
# 1           1          11   2       1  10.42  11.24  12.8    0.51899   0.82
# 2           2          11   3       2  12.82  13.64  15.2    0.51899   0.82
# 3           3          11   4       3  15.22  16.04  17.6    0.51899   0.82
# 4           4          11   5       4  17.62  18.44  20.0    0.51899   0.82
#
#    eTime  ...         tvi2        tve2  x0_index  abs_time_at_BS  \
# 0   0.02  ...  1727.205556    0.000000       519               -
# 1   1.58  ...   582.526667  423.569444        41               -
# 2   1.58  ...   547.486667  432.711111        41               -
# 3   1.58  ...   534.165556  466.033611        41               -
# 4   1.58  ...   511.495556  492.872222        41               -
#
#    abs_time_at_x0  abs_time_at_BE  rel_time_at_BS  rel_time_at_x0  \
# ...

# %%
patient11
# Out:
#        Unnamed: 0  Patient Id     BN  ventBN        BS      IEnd        BE  \
# 0               0          11      1       0      0.02     10.40     10.40
# 1               1          11      2       1     10.42     11.24     12.80
# 2               2          11      3       2     12.82     13.64     15.20
# 3               3          11      4       3     15.22     16.04     17.60
# 4               4          11      5       4     17.62     18.44     20.00
# ...           ...         ...    ...     ...       ...       ...       ...
# 36880       36880          11  36881    4993  96058.90  96059.64  96061.96
# 36881       36881          11  36882    4994  96061.98  96062.78  96068.00
# 36882       36882          11  36883    4995  96068.02  96068.82  96071.54
# 36883       36883          11  36884    4996  96071.56  96072.40  96075.16
# 36884       36884          11  36885    4997  96075.18  96076.00  96078.28
#
# ...
