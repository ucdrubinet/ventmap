# %% [markdown]
# # API
#
# ## Basics
# For reading ventilator data:

# %%
from io import open

from ventmap.raw_utils import extract_raw

# create generator that will iterate through file. Specify False to ensure that
# breaths without BS/BE markers will be dropped. If you say True, then breaths
# without BS/BE will be kep?t
filepath ="/data/aim2/experiment1/all_data/raw/0700RPI21/0700RPI2120190219-rpi21-2019-02-19-01-01-01.749347.csv"
generator = extract_raw(open(filepath), False)
for breath in generator:
    # breath data is output in dictionary format
    flow, pressure = breath['flow'], breath['pressure']

# %% [markdown]
# If you want to preprocess a breath file for later usage, or if you intend to process it again then it is suggested to use the `process_breath_file` method

# %%
from io import open

from ventmap.raw_utils import process_breath_file, read_processed_file

# This function will output 2 files. The first will just contain raw breath data
# the other will contain higher level processed data
process_breath_file(open(filepath), False, 'new_filename')
raw_filepath_name = 'new_filename.raw.npy'
processed_filepath_name = 'new_filename.processed.npy'

for breath in read_processed_file(raw_filepath_name, processed_filepath_name):
    # breath data is output in dictionary format
    flow, pressure = breath['flow'], breath['pressure']

# %%
breath
# Out:
# {'rel_bn': 1916,
#  'vent_bn': 4128,
#  'flow': [1.36,
#   5.92,
#   17.08,
#   30.73,
#   41.89,
#   49.57,
#   52.28,
#   46.58,
#   41.9,
#   37.84,
#   35.71,
#   33.0,
#   31.05,
#   29.51,
#   27.98,
#   26.51,
#   25.3,
#   24.23,
#   23.45,
#   23.63,
#   22.67,
#   21.84,
#   20.93,
#   20.24,
#   17.77,
#   17.33,
#   15.32,
#   14.65,
#   13.64,
#   13.11,
#   11.57,
#   11.37,
#   11.15,
#   10.74,
#   10.02,
#   9.1,
#   7.34,
#   5.92,
#   6.45,
#   5.35,
#   4.93,
#   4.25,
#   4.44,
#   3.56,
#   4.16,
#   4.55,
#   -36.86,
#   -56.03,
#   -49.85,
#   -28.58,
#   -23.35,
#   -25.81,
#   -31.52,
#   -29.56,
#   -26.77,
#   -25.6,
#   -25.3,
#   -23.77,
#   -23.76,
#   -22.38,
#   -22.66,
#   -21.52,
#   -21.51,
#   -19.78,
#   -20.16,
#   -18.53,
#   -17.52,
#   -16.1,
#   -15.31,
#   -14.43,
#   -14.55,
#   -14.99,
#   -13.55,
#   -13.67,
#   -12.7,
#   -12.29,
#   -11.75,
#   -12.19,
#   -11.04,
#   -10.06,
#   -9.22,
#   -9.13,
#   -8.31,
#   -7.91,
#   -7.94,
#   -6.76,
#   -6.73,
#   -6.5,
#   -6.06,
#   -5.43,
#   -5.64,
#   -4.65,
#   -4.33,
#   -4.06,
#   -3.9,
#   -3.8,
#   -3.88,
#   -4.29,
#   -4.15,
#   -4.01,
#   -3.99,
#   -3.57,
#   -2.88,
#   -1.95,
#   -0.71,
#   -0.7,
#   -0.99,
#   -1.34,
#   -1.39,
#   -2.26,
#   -2.31,
#   -2.4,
#   -2.27,
#   -2.73,
#   -2.47,
#   -1.91,
#   -1.49,
#   -1.41,
#   -1.2,
#   -1.34,
#   -1.2,
#   -1.41,
#   -1.36,
#   -1.26,
#   -1.34,
#   -1.17,
#   -0.98,
#   9.96,
#   9.96,
#   9.98,
#   10.04,
#   10.12,
#   10.17,
#   10.17,
#   10.14,
#   10.09,
#   9.98,
#   9.98,
#   9.89,
#   9.87,
#   9.83,
#   9.93,
#   10.09,
#   10.09,
#   10.03,
#   9.97,
#   10.02,
#   9.95,
#   10.0,
#   10.03,
#   9.95,
#   9.85,
#   9.84,
#   9.9,
#   9.86,
#   9.85,
#   9.83,
#   9.83,
#   9.84,
#   9.83,
#   9.83,
#   9.84,
#   9.84,
#   9.83,
#   9.82,
#   9.84,
#   9.91,
#   10.0,
#   10.0,
#   10.0,
#   9.86,
#   10.0,
#   9.93,
#   9.92,
#   9.77,
#   9.74,
#   9.81,
#   9.97,
#   10.09,
#   10.03,
#   10.02,
#   10.02,
#   10.02,
#   10.02,
#   10.05,
#   10.02,
#   9.95,
#   9.86,
#   9.93,
#   9.93,
#   9.93,
#   9.93,
#   9.93,
#   9.93,
#   9.91,
#   9.84,
#   9.83,
#   9.84,
#   9.84,
#   9.83,
#   9.83,
#   9.91,
#   9.92,
#   10.0,
#   10.0,
#   9.93,
#   9.93,
#   9.92,
#   9.85,
#   9.77,
#   9.74,
#   9.8,
#   9.99,
#   10.16,
#   10.1,
#   10.03],
#  'abs_bs': None,
#  'bs_time': 7221.56,
#  'frame_dur': 4.3,
#  'dt': 0.02}

# %%
breath.keys()
# Out:
# dict_keys(['rel_bn', 'vent_bn', 'flow', 'pressure', 'abs_bs', 'bs_time', 'frame_dur', 'dt'])

# %% [markdown]
# For extracting metadata (I-Time, TVe, TVi) from files.

# %%
from ventmap.breath_meta import get_file_breath_meta

# Data output is normally in list format. Ordering information can be found in
# ventmap.constants.META_HEADER.
# breath_meta = get_file_breath_meta(filepath)
# If you want a pandas DataFrame then you can set the optional argument to_data_frame=True
filepath ="/data/aim2/experiment1/all_data/raw/0700RPI21/0700RPI2120190219-rpi21-2019-02-19-01-01-01.749347.csv"


breath_meta = get_file_breath_meta(filepath, to_data_frame=True)
# Out:
# file is a str name, opening it using open
# ['Patient Id', 'BN', 'ventBN', 'BS', 'IEnd', 'BE', 'I:E ratio', 'iTime', 'eTime', 'inst_RR', 'tvi', 'tve', 'tve:tvi ratio', 'maxF', 'minF', 'maxP', 'PIP', 'Maw', 'PEEP', 'ipAUC', 'epAUC', ' ', 'BS.1', 'x01', 'tvi1', 'tve1', 'x02', 'tvi2', 'tve2', 'x0_index', 'abs_time_at_BS', 'abs_time_at_x0', 'abs_time_at_BE', 'rel_time_at_BS', 'rel_time_at_x0', 'rel_time_at_BE', 'min_pressure']
# [['BN', 'ventBN', 'BS', 'IEnd', 'BE', 'I:E ratio', 'iTime', 'eTime', 'inst_RR', 'tvi', 'tve', 'tve:tvi ratio', 'maxF', 'minF', 'maxP', 'PIP', 'Maw', 'PEEP', 'ipAUC', 'epAUC', ' ', 'BS.1', 'x01', 'tvi1', 'tve1', 'x02', 'tvi2', 'tve2', 'x0_index', 'abs_time_at_BS', 'abs_time_at_x0', 'abs_time_at_BE', 'rel_time_at_BS', 'rel_time_at_x0', 'rel_time_at_BE', 'min_pressure']]
# 1914  2019-02-19 03-00-59.941320         7217.26         7218.18
# 1915  2019-02-19 03-01-04.356020         7221.56         7222.48
#
#       rel_time_at_BE  min_pressure
# 0               4.30         17.25
# 1               8.54         17.13
# 2              12.84         17.09
# 3              17.14         16.94
# 4              21.44         16.88
# ...              ...           ...
# 1911         7209.08         17.74
# 1912         7212.96         17.69
# 1913         7217.24         17.74
# 1914         7221.54         17.68
# 1915         7225.84         17.41
#
# [1916 rows x 36 columns]

# %%
breath_meta.to_excel("random.xlsx")

# %% [markdown]
# Take a look at the `metadata` dataframe

# %%
breath_meta.head()
# Out:
#    BN  ventBN     BS   IEnd     BE  I:E ratio  iTime  eTime    inst_RR  \
# 0   1    2213   0.02   0.94   4.30    0.27219   0.92   3.38  13.953488
# 1   2    2214   4.32   5.24   8.54    0.27711   0.92   3.32  14.150943
# 2   3    2215   8.56   9.48  12.84    0.27219   0.92   3.38  13.953488
# 3   4    2216  12.86  13.78  17.14    0.27219   0.92   3.38  13.953488
# 4   5    2217  17.16  18.08  21.44    0.27219   0.92   3.38  13.953488
#
#           tvi  ...        tvi2        tve2  x0_index  abs_time_at_BS  \
# 0  384.407500  ...  384.407500  372.316111        46               -
# 1  357.682222  ...  357.682222  330.920000        46               -
# 2  359.044722  ...  359.044722  339.396944        46               -
# 3  345.575556  ...  345.575556  338.113056        46               -
# 4  347.510278  ...  347.510278  345.029167        46               -
#
#    abs_time_at_x0  abs_time_at_BE  rel_time_at_BS  rel_time_at_x0  \
# 0               -               -            0.02            0.94
# 1               -               -            4.32            5.24
# 2               -               -            8.56            9.48
# 3               -               -           12.86           13.78
# 4               -               -           17.16           18.08
#
#    rel_time_at_BE  min_pressure
# 0            4.30         17.25
# 1            8.54         17.13
# 2           12.84         17.09
# 3           17.14         16.94
# 4           21.44         16.88
#
# [5 rows x 36 columns]

# %% [markdown]
# ##

# %%
from io import open

from ventmap.raw_utils import extract_raw


filepath = "/data/vwd-deidentified-data/011/011-2009-03-03-22-33-02.957.csv"
generator = extract_raw(open(filepath), False)
for idx,breath in enumerate(generator):
    # breath data is output in dictionary format
    flow, pressure = breath['flow'], breath['pressure']
    print(breath)
    if idx==5:
        break
# Out:
# deidentified_study_id,breath_datetime,flow,pressure 51 4
# This is of new format
# Every row follows => pt _id, timestamp, flow,pressure
# {'pt_id': 11, 'rel_bn': 1, 'vent_bn': 0, 'flow': [10.43, 10.0, 9.87, 10.08, 9.38, 9.96, 10.02, 9.95, 9.67, 10.38, 9.99, 10.33, 10.0, 9.81, 9.86, 10.14, 9.8, 10.38, 9.79, 9.98, 9.92, 10.05, 9.71, 10.03, 9.74, 9.73, 10.04, 10.17, 9.98, 9.84, 10.27, 10.09, 9.92, 10.2, 10.38, 9.98, 9.79, 9.95, 10.04, 10.25, 10.15, 10.13, 10.04, 9.89, 10.09, 9.85, 9.85, 10.0, 10.13, 9.96, 10.13, 10.11, 10.04, 9.83, 10.01, 10.2, 10.02, 9.98, 10.26, 9.87, 10.04, 9.92
# {'pt_id': 11, 'rel_bn': 6, 'vent_bn': 5, 'flow': [-1.21, 5.13, 19.04, 43.4, 61.28, 79.89, 84.83, 74.41, 67.13, 61.26, 60.98, 57.05, 56.09, 53.36, 52.07, 51.84, 51.87, 50.09, 50.5, 49.13, 48.53, 46.82, 44.24, 42.34, 40.36, 39.54, 36.99, 36.21, 33.06, 29.98, 28.58, 26.36, 24.73, 22.11, 21.21, 20.13, 18.85, 17.68, 15.89, 14.19, 12.81, -66.39, -83.05, -80.12, -57.91, -50.96, -47.63, -47.88, -45.22, -41.93, -39.28, -38.28, -36.99, -35.29, -33.46, -31.54, -31.41, -29.47, -28.32, -27.48, -27.36, -25.53, -24.37, -23.42, -22.3, -22.33, -20.31, -20.23, -20.33, -20.25, -19.79, -19.08, -18.07, -17.66, -16.62, -16.25, -15.39, -14.9, -13.32, -12.66, -12.13, -12.68, -12.47, -11.73, -11.83, -11.41, -11.29, -10.4, -9.7, -9.88, -10.14, -8.96, -8.39, -8.18, -8.55, -8.25, -7.88, -8.17, -9.63, -9.0, -8.03, -7.93, -7.37, -7.18, -5.71, -4.83, -3.61, -2.87, -2.52, -2.27, -2.54, -2.57, -2.18, -2.26, -2.14, -2.55, -2.2, -2.45, -2.41, -2.34], 'pressure': [6.95, 7.05, 8.14, 10.57, 13.16, 16.8, 21.53, 24.9, 26.24, 26.82, 27.21, 27.42, 27.6, 27.68, 27.81, 27.73, 27.74, 28.08, 28.07, 28.28, 28.28, 28.41, 28.63, 28.6, 28.66, 28.53, 28.54, 28.41, 28.61, 28.7, 28.54, 28.6, 28.59, 28.51, 28.43, 28.43, 28.47, 28.4, 28.4, 28.48, 28.55, 28.3, 24.13, 16.86, 11.35, 10.25, 10.27, 10.22, 9.8, 9.55, 9.31, 9.26, 9.04, 8.89, 8.74, 8.67, 8.66, 8.51, 8.39, 8.28, 8.28, 8.13, 8.09, 7.98, 8.01, 8.02, 7.97, 7.88, 7.89, 7.88, 7.79, 7.85, 7.74, 7.73, 7.63, 7.6, 7.5, 7.41, 7.36, 7.35, 7.34, 7.43, 7.43, 7.41, 7.33, 7.32, 7.31, 7.29, 7.36, 7.37, 7.29, 7.19, 7.24, 7.25, 7.27, 7.33, 7.32, 7.41, 7.44, 7.34, 7.17, 7.16, 7.15, 7.14, 6.95, 6.85, 6.82, 6.89, 6.97, 6.97, 7.05, 6.97, 6.96, 6.97, 7.04, 7.05, 7.05, 7.05, 6.97, 6.97], 'bs_time': 20.02, 'frame_dur': 2.4, 'dt': 0.02, 'abs_bs': None}

# %%
print(len(generator))
# Out:
# 3014

# %%
from ventmap.breath_meta import get_file_breath_meta,get_file_experimental_breath_meta

# Data output is normally in list format. Ordering information can be found in
# ventmap.constants.META_HEADER.
# breath_meta = get_file_breath_meta(filepath)
# If you want a pandas DataFrame then you can set the optional argument to_data_frame=True

# filepath = "/data/vwd-deidentified-data/011/011-consolidate-vwd-2009-03-03-22-33-02.957.csv"
filepath = "/data/vwd-deidentified-data/138/138-consolidate-vwd-2016-06-07-22-04-37.623.csv"

breath_meta = get_file_experimental_breath_meta(filepath, to_data_frame=True,new_format=True)
# breath_meta = get_file_breath_meta(filepath, to_data_frame=True,new_format=True)
# Out:
# file is a str name, opening it using open
# deidentified_study_id,breath_datetime,flow,pressure 51 4
# This is of new format
# Every row follows => pt _id, timestamp, flow,pressure
# -
# [-2.39, 61.25, 60.21, 61.09, 60.79, 59.42, 62.37, 62.17, 60.41, 61.57, 61.7, 62.17, 61.7, 60.08, 59.89, 60.8, 61.99, 62.17, 60.94, 61.64, 61.94, 62.97, 61.36, 61.95, 62.18, 61.56, 61.42, 61.03, 61.37, -91.98, -99.28, -73.42, -33.28, -29.81, -35.64, -45.05, -43.46, -41.76, -37.27, -37.34, -37.76, -35.9, -34.03, -34.89, -33.84, -34.32, -31.75, -31.21, -30.38, -28.57, -28.57, -28.23, -27.46, -25.61, -26.5, -25.34, -23.57, -22.55, -22.95, -22.75, -21.54, -21.69, -20.62, -19.68, -17.61, -18.29, -18.18, -16.91, -17.33, -17.79, -17.68, -15.49, -16.12, -16.1, -14.69, -14.39, -14.55, -15.4, -13.58, -13.81, -13.33, -13.06, -11.67, -12.06, -11.63, -10.16, -10.52, -10.03, -9.91, -8.44, -9.02, -9.0, -7.36, -6.71, -5.78, -5.26, -3.84, -3.88, -4.04, -4.65, -4.94, -5.46, -5.53, -5.08, -5.11, -5.28, -5.29, -5.23, -5.28, -5.37, -4.82, -4.45, -3.97, -3.57, -2.99, -2.98, -3.05, -2.71, -2.32, -2.01]
# ----------------------------------------------------------
# TypeError                Traceback (most recent call last)
# Cell In[1], line 11
#       3 # Data output is normally in list format. Ordering information can be found in
#       4 # ventmap.constants.META_HEADER.
#       5 # breath_meta = get_file_breath_meta(filepath)
#       6 # If you want a pandas DataFrame then you can set the optional argument to_data_frame=True
#       7
#       8 # filepath = "/data/vwd-deidentified-data/011/011-consolidate-vwd-2009-03-03-22-33-02.957.csv"
#       9 filepath = "/data/vwd-deidentified-data/138/138-consolidate-vwd-2016-06-07-22-04-37.623.csv"
# ---> 11 breath_meta = get_file_experimental_breath_meta(filepath, to_data_frame=True,new_format=True)
#      12 # breath_meta = get_file_breath_meta(filepath, to_data_frame=True,new_format=True)
#
# File /data1/srsrai/ventmap/ventMAP/ventmap/breath_meta.py:37, in get_file_experimental_breath_meta(file, tve_pos, ignore_missing_bes, rel_bn_interval, vent_bn_interval, to_data_frame, new_format, spec_vent_bns, spec_rel_bns)
#      36 def get_file_experimental_breath_meta(file, tve_pos=True, ignore_missing_bes=True, rel_bn_interval=[], vent_bn_interval=[], to_data_frame=False,new_format=False, spec_vent_bns=[], spec_rel_bns=[]):
# ---> 37     return _get_file_breath_meta(
#      38         get_experimental_breath_meta, file, tve_pos, ignore_missing_bes,
#      39         rel_bn_interval, vent_bn_interval, to_data_frame, spec_vent_bns, spec_rel_bns,new_format,EXPERIMENTAL_META_HEADER
#      40     )
#
# File /data1/srsrai/ventmap/ventMAP/ventmap/breath_meta.py:72, in _get_file_breath_meta(func, file, tve_pos, ignore_missing_bes, rel_bn_interval, vent_bn_interval, to_data_frame, spec_vent_bns, spec_rel_bns, new_format, META_HEADER)
#      68     else:  # case the file is a file descriptor
#      70         for breath in extract_raw(file, ignore_missing_bes,rel_bn_interval=rel_bn_interval, vent_bn_interval=vent_bn_interval,spec_vent_bns=spec_vent_bns, spec_rel_bns=spec_rel_bns):
#      71 #             print("one breath",breath)
# ---> 72             array.append(func(breath))
#      74     if not to_data_frame:
#      75         return array
#
# File /data1/srsrai/ventmap/ventMAP/ventmap/breath_meta.py:334, in get_experimental_breath_meta(breath, tve_pos)
#     332 print(x0_index)
#     333 print(flow)
# --> 334 eFlow = flow[x0_index:]  # technically this might need to be +1
#     336 # convert tvi to liters. Units are L / cm H20
#     337 dyn_compliance = (tvi / 1000) / (PIP - peep)
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
breath_meta
# Out:
#        Patient Id     BN  ventBN        BS      IEnd        BE  I:E ratio  \
# 0              11      1       0      0.02     10.40     10.40  519.00000
# 1              11      2       1     10.42     11.24     12.80    0.51899
# 2              11      3       2     12.82     13.64     15.20    0.51899
# 3              11      4       3     15.22     16.04     17.60    0.51899
# 4              11      5       4     17.62     18.44     20.00    0.51899
# ...           ...    ...     ...       ...       ...       ...        ...
# 36880          11  36881    4993  96058.90  96059.64  96061.96    0.31624
# 36881          11  36882    4994  96061.98  96062.78  96068.00    0.15267
# 36882          11  36883    4995  96068.02  96068.82  96071.54    0.29197
# 36883          11  36884    4996  96071.56  96072.40  96075.16    0.30216
# 36884          11  36885    4997  96075.18  96076.00  96078.28    0.35652
#
#        iTime  eTime    inst_RR  ...         tvi2        tve2  x0_index  \
# 0      10.38   0.02   5.769231  ...  1727.205556    0.000000       519
# 1       0.82   1.58  25.000000  ...   582.526667  423.569444        41
# 2       0.82   1.58  25.000000  ...   547.486667  432.711111        41
# 3       0.82   1.58  25.000000  ...   534.165556  466.033611        41
# 4       0.82   1.58  25.000000  ...   511.495556  492.872222        41
# ...      ...    ...        ...  ...          ...         ...       ...
# 36880   0.74   2.34  19.480519  ...   390.305556  412.210833        37
# 36881   0.80   5.24   9.933775  ...   418.501944  453.755556        40
# 36882   0.80   2.74  16.949153  ...   403.516111  402.839722        40
# 36883   0.84   2.78  16.574586  ...   419.417500  417.149444        42
# 36884   0.82   2.30  19.230769  ...   422.296667  416.842222        41
#
#        abs_time_at_BS  abs_time_at_x0  abs_time_at_BE  rel_time_at_BS  \
# 0                   -               -               -            0.02
# 1                   -               -               -           10.42
# 2                   -               -               -           12.82
# 3                   -               -               -           15.22
# 4                   -               -               -           17.62
# ...               ...             ...             ...             ...
# 36880               -               -               -        96058.90
# 36881               -               -               -        96061.98
# 36882               -               -               -        96068.02
# 36883               -               -               -        96071.56
# 36884               -               -               -        96075.18
#
#        rel_time_at_x0  rel_time_at_BE  min_pressure
# 0               10.40           10.40          0.50
# 1               11.24           12.80         16.62
# 2               13.64           15.20         16.33
# 3               16.04           17.60         16.15
# 4               18.44           20.00         16.61
# ...               ...             ...           ...
# 36880        96059.64        96061.96         11.38
# 36881        96062.78        96068.00         11.38
# 36882        96068.82        96071.54         10.76
# 36883        96072.40        96075.16         11.45
# 36884        96076.00        96078.28         11.45
#
# [36885 rows x 37 columns]

# %%
import pandas
breath_meta.to_excel("/data/patientid_11_vwd_summary.xlsx")
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x7f7a5c1a6700>
# Traceback (most recent call last):
#   File "/data1/customconda/envs/ards/lib/python3.8/zipfile.py", line 1821, in __del__
#     self.close()
#   File "/data1/customconda/envs/ards/lib/python3.8/zipfile.py", line 1838, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas
# ----> 2 breath_meta.to_excel("/data/patientid_11_vwd_summary.xlsx")
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/pandas/core/generic.py:2252, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options)
#    2239 from pandas.io.formats.excel import ExcelFormatter
#    2241 formatter = ExcelFormatter(
#    2242     df,
#    2243     na_rep=na_rep,
#    (...)
#    2250     inf_rep=inf_rep,
#    2251 )
# -> 2252 formatter.write(
#    2253     excel_writer,
#    2254     sheet_name=sheet_name,
#    2255     startrow=startrow,
#    2256     startcol=startcol,
#    2257     freeze_panes=freeze_panes,
#    2258     engine=engine,
#    2259     storage_options=storage_options,
#    2260 )
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/pandas/io/formats/excel.py:950, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     947 finally:
#     948     # make sure to close opened file handles
#     949     if need_save:
# --> 950         writer.close()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/pandas/io/excel/_base.py:1326, in ExcelWriter.close(self)
#    1324 def close(self) -> None:
#    1325     """synonym for save, to make it more file-like"""
# -> 1326     self._save()
#    1327     self._handles.close()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py:109, in OpenpyxlWriter._save(self)
#     105 def _save(self) -> None:
#     106     """
#     107     Save workbook to disk.
#     108     """
# --> 109     self.book.save(self._handles.handle)
#     110     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     111         # truncate file to the written content
#     112         self._handles.handle.truncate()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/workbook/workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# --> 407 save_workbook(self, filename)
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/writer/excel.py:293, in save_workbook(workbook, filename)
#     291 archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292 writer = ExcelWriter(workbook, archive)
# --> 293 writer.save()
#     294 return True
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/writer/excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/writer/excel.py:75, in ExcelWriter.write_data(self)
#      72 else:
#      73     archive.writestr(ARC_THEME, theme_xml)
# ---> 75 self._write_worksheets()
#      76 self._write_chartsheets()
#      77 self._write_images()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/writer/excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/writer/excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/worksheet/_writer.py:361, in openpyxl.worksheet._writer.WorksheetWriter.write()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/worksheet/_writer.py:369, in openpyxl.worksheet._writer.WorksheetWriter.close()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/worksheet/_writer.py:288, in get_stream()
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/openpyxl/worksheet/_writer.py:289, in openpyxl.worksheet._writer.WorksheetWriter.get_stream()
#
# File /data1/customconda/envs/ards/lib/python3.8/contextlib.py:120, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     118 if type is None:
#     119     try:
# --> 120         next(self.gen)
#     121     except StopIteration:
#     122         return False
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/et_xmlfile/xmlfile.py:50, in _FakeIncrementalFileWriter.element(self, tag, attrib, nsmap, **_extra)
#      48     self._top_element = parent
#      49 else:
# ---> 50     self._write_element(el)
#      51     self._top_element = None
#
# File /data1/customconda/envs/ards/lib/python3.8/site-packages/et_xmlfile/xmlfile.py:78, in _FakeIncrementalFileWriter._write_element(self, element)
#      76 def _write_element(self, element):
#      77     xml = tostring(element)
# ---> 78     self._file.write(xml)
#
# OSError: [Errno 28] No space left on device

# %%
breath_meta.head()

# %% [markdown]
# For extracting Experimental Breath Metadata from files, which have some pieces of more experimental information that have been developed since 2017 paper.

# %%
from ventmap.breath_meta import get_file_experimental_breath_meta

# Data output is normally in list format. Ordering information can be found in
# ventmap.constants.META_HEADER.
exp_breath_meta = get_file_experimental_breath_meta(<filepath to vent data>)
# If you want a pandas DataFrame then you can set the optional argument to_data_frame=True
exp_breath_meta = get_file_experimental_breath_meta(<filepath to vent data>, to_data_frame=True)

# %% [markdown]
# Take a look at the Experimental Breath Metadata dataframe

# %%
exp_breath_meta.head()
# Out:
#    BN  ventBN     BS   IEnd     BE  I:E ratio  iTime  eTime    inst_RR  \
# 0   1   53946   0.02   2.52   9.40    0.36232   2.50   6.90   6.382979
# 1   2   53947   9.42  11.72  18.36    0.34535   2.30   6.66   6.696429
# 2   3   53948  18.38  20.78  27.98    0.33241   2.40   7.22   6.237006
# 3   4   53949  28.00  29.34  30.82    0.89333   1.34   1.50  21.126761
# 4   5   53950  30.84  31.80  32.96    0.81356   0.96   1.18  28.037383
#
#            tvi  ...  dyn_compliance  vol_at_.5_sec  vol_at_.76_sec  \
# 0  2129.422222  ...        0.218268    -510.342222     -882.069167
# 1  2261.646667  ...        0.212441    -639.298889     -958.682778
# 2   744.514444  ...        0.081617    -186.508889     -257.480278
# 3   402.528889  ...        0.044885    -169.228889     -198.612222
# 4   383.351111  ...        0.043672    -195.342222     -271.551111
#
#    vol_at_1_sec  pressure_itime_4  pressure_itime_5  pressure_itime_6  \
# 0  -1095.104722              3.36              3.20              3.14
# 1  -1147.471667              3.08              2.90              2.86
# 2   -305.858056              2.44              2.42              2.42
# 3   -200.667500              1.38              1.36              1.36
# 4   -316.975556              0.98              0.98              0.96
#
#    pressure_itime_by_pip5  pressure_itime_by_pip6  pressure_itime_from_front
# 0                    3.34                    3.38                       2.56
# 1                    2.88                    3.02                       2.36
# 2                    2.44                    2.46                       2.46
# 3                    1.38                    1.44                       1.40
# 4                    1.00                    1.12                       1.02
#
# [5 rows x 49 columns]

# %%
exp_breath_meta.shape
# Out:
# (96, 49)

# %% [markdown]
# ## Adding new features - example
#
# The information you can use from raw data file are:

# %%
breath.keys()
# Out:
# dict_keys(['rel_bn', 'vent_bn', 'flow', 'pressure', 'abs_bs', 'bs_time', 'frame_dur', 'dt'])

# %% [markdown]
# If you want to create a new feature, first define your feature as below:
# For example, if you want to calculate the time between the Maximum of flow and the Minimun of flow for each breath.

# %%
import pandas as pd
def time_btw_max_min_flow(breath):
    flow = breath['flow']
    dt = breath['dt']
    btw_time = abs((flow.index(max(flow)) - flow.index(min(flow)))*dt)
    return round(btw_time,2)

# %% [markdown]
# And then add you function at here, implement `extract_new_feature`, return a list `feature_values` for your new feature.

# %%
def extract_new_feature(file):
    feature_values = []
    for breath in extract_raw(file, True):
        #TODO: add new feature function
        btw_time = time_btw_max_min_flow(breath)
        feature_values.append(btw_time)
    return feature_values

btw_times = extract_new_feature(open(<filepath to vent data>))

# %% [markdown]
# Finally, add this new feature to your original dataframe.

# %%
exp_breath_meta['time_btw_max_min'] = btw_times

# %% [markdown]
# Take a look at the dataframe `exp_breath_meta` having one more feature `time_btw_max_min` at the end.

# %%
exp_breath_meta.head()
# Out:
#    BN  ventBN     BS   IEnd     BE  I:E ratio  iTime  eTime    inst_RR  \
# 0   1   53946   0.02   2.52   9.40    0.36232   2.50   6.90   6.382979
# 1   2   53947   9.42  11.72  18.36    0.34535   2.30   6.66   6.696429
# 2   3   53948  18.38  20.78  27.98    0.33241   2.40   7.22   6.237006
# 3   4   53949  28.00  29.34  30.82    0.89333   1.34   1.50  21.126761
# 4   5   53950  30.84  31.80  32.96    0.81356   0.96   1.18  28.037383
#
#            tvi  ...  vol_at_.5_sec  vol_at_.76_sec  vol_at_1_sec  \
# 0  2129.422222  ...    -510.342222     -882.069167  -1095.104722
# 1  2261.646667  ...    -639.298889     -958.682778  -1147.471667
# 2   744.514444  ...    -186.508889     -257.480278   -305.858056
# 3   402.528889  ...    -169.228889     -198.612222   -200.667500
# 4   383.351111  ...    -195.342222     -271.551111   -316.975556
#
#    pressure_itime_4  pressure_itime_5  pressure_itime_6  \
# 0              3.36              3.20              3.14
# 1              3.08              2.90              2.86
# 2              2.44              2.42              2.42
# 3              1.38              1.36              1.36
# 4              0.98              0.98              0.96
#
#    pressure_itime_by_pip5  pressure_itime_by_pip6  pressure_itime_from_front  \
# 0                    3.34                    3.38                       2.56
# 1                    2.88                    3.02                       2.36
# 2                    2.44                    2.46                       2.46
# 3                    1.38                    1.44                       1.40
# 4                    1.00                    1.12                       1.02
#
#    time_btw_max_min
# 0              1.88
# 1              1.22
# 2              2.02
# 3              1.20
# 4              0.82
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Extras
# Clear null bytes from a file

# %%
from io import open

from ventmap.clear_null_bytes import clear_descriptor_null_bytes

cleared_descriptor = clear_descriptor_null_bytes(open(<filepath to vent data>))

# %% [markdown]
# Cut a file into specific BN interval and store for later use

# %%
from io import open

from ventmap.cut_breath_section import cut_breath_section

# get file descriptor for the truncated data
new_descriptor = cut_breath_section(open(<filepath to vent data>), <breath start num>, <breath end num>)
# write output to file
with open('new_file', 'w') as f:
    f.write(new_descriptor.read())

# %% [markdown]
# Check if there is a plateau pressure in a breath

# %%
from io import open

from ventmap.raw_utils import extract_raw
from ventmap.SAM import check_if_plat_occurs

generator = extract_raw(open(<filepath to vent data>), False)
for breath in generator:
    flow, pressure = breath['flow'], breath['pressure']

    # .02 is the sampling rate for the PB-840 corresponding with 1 obs every .02 seconds
    did_plat_occur = check_if_plat_occurs(flow, pressure, .02)
